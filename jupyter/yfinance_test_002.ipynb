# %%
import datetime as dt
import mplfinance as mpf
import yfinance as yf

# %%
ticker = yf.Ticker('^N225')
df = ticker.history(period='6mo')
df
# Out:
#                                    Open          High           Low  \
# Date
# 2024-02-02 00:00:00+09:00  36249.988281  36441.089844  36083.609375
# 2024-02-05 00:00:00+09:00  36419.339844  36452.621094  36213.000000
# 2024-02-06 00:00:00+09:00  36249.078125  36294.480469  36065.980469
# 2024-02-07 00:00:00+09:00  36002.988281  36195.500000  35854.628906
# 2024-02-08 00:00:00+09:00  36258.839844  36956.968750  36206.199219
# ...                                 ...           ...           ...
# 2024-07-29 00:00:00+09:00  38139.121094  38719.699219  38010.011719
# 2024-07-30 00:00:00+09:00  38241.351562  38531.160156  38076.699219
# 2024-07-31 00:00:00+09:00  38140.769531  39188.371094  37954.378906
# 2024-08-01 00:00:00+09:00  38781.558594  38781.558594  37737.878906
# 2024-08-02 00:00:00+09:00  37444.171875  37471.519531  35880.148438
#
#                                   Close     Volume  Dividends  Stock Splits
# Date
# 2024-02-02 00:00:00+09:00  36158.019531  114800000        0.0           0.0
# 2024-02-05 00:00:00+09:00  36354.160156  130500000        0.0           0.0
# 2024-02-06 00:00:00+09:00  36160.660156  134700000        0.0           0.0
# 2024-02-07 00:00:00+09:00  36119.921875  126500000        0.0           0.0
# 2024-02-08 00:00:00+09:00  36863.281250  151000000        0.0           0.0
# ...                                 ...        ...        ...           ...
# 2024-07-29 00:00:00+09:00  38468.628906  107300000        0.0           0.0
# 2024-07-30 00:00:00+09:00  38525.949219  109700000        0.0           0.0
# 2024-07-31 00:00:00+09:00  39101.820312  146400000        0.0           0.0
# 2024-08-01 00:00:00+09:00  38126.328125  178800000        0.0           0.0
# 2024-08-02 00:00:00+09:00  35909.699219  204300000        0.0           0.0
#
# [124 rows x 7 columns]

# %%
ticker.history_metadata
# Out:
# {'currency': 'JPY',
#  'symbol': '^N225',
#  'exchangeName': 'OSA',
#  'fullExchangeName': 'Osaka',
#  'instrumentType': 'INDEX',
#  'firstTradeDate': -157420800,
#  'regularMarketTime': 1722579302,
#  'hasPrePostMarketData': False,
#  'gmtoffset': 32400,
#  'timezone': 'JST',
#  'exchangeTimezoneName': 'Asia/Tokyo',
#  'regularMarketPrice': 35909.7,
#  'fiftyTwoWeekHigh': 37471.52,
#  'fiftyTwoWeekLow': 35880.15,
#  'regularMarketDayHigh': 37471.52,
#  'regularMarketDayLow': 35880.15,
#  'regularMarketVolume': 0,
#  'chartPreviousClose': 36158.02,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'JST',
#    'start': 1722556800,
#    'end': 1722556800,
#    'gmtoffset': 32400},
#   'regular': {'timezone': 'JST',
#    'start': 1722556800,
#    'end': 1722578400,
#    'gmtoffset': 32400},
#   'post': {'timezone': 'JST',
#    'start': 1722578400,
#    'end': 1722578400,
#    'gmtoffset': 32400}},
#  'dataGranularity': '1d',
#  'range': '6mo',
#  'validRanges': ['1d',
#   '5d',
#   '1mo',
#   '3mo',
#   '6mo',
#   '1y',
#   '2y',
#   '5y',
#   '10y',
#   'ytd',
#   'max']}

# %%
mpf.plot(df, type='candle', style='binance', figratio=(12, 4))
