# %%
import datetime as dt
import mplfinance as mpf
import yfinance as yf

# %%
end = dt.datetime.now(dt.timezone(dt.timedelta(hours=9)))
delta = dt.timedelta(hours=6)
start = end - delta * 12
print('start :', start)
print('end   :', end)
# Out:
# start : 2024-08-02 07:54:28.939344+09:00
# end   : 2024-08-05 07:54:28.939344+09:00

# %%
ticker = yf.Ticker('USDJPY=X')
df = ticker.history(start=start, end=end, interval='1m')
df
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-08-01 23:55:00+01:00  149.319000  149.320999  149.257004  149.281998
# 2024-08-01 23:56:00+01:00  149.285004  149.319000  149.279999  149.315994
# 2024-08-01 23:57:00+01:00  149.309006  149.341003  149.309006  149.330994
# 2024-08-01 23:58:00+01:00  149.334000  149.343994  149.317001  149.317001
# 2024-08-02 00:00:00+01:00  149.304001  149.311005  149.246994  149.272995
# ...                               ...         ...         ...         ...
# 2024-08-02 21:55:00+01:00  146.567993  146.574997  146.507004  146.528000
# 2024-08-02 21:56:00+01:00  146.526993  146.539993  146.475006  146.535004
# 2024-08-02 21:57:00+01:00  146.542999  146.550003  146.468002  146.481995
# 2024-08-02 21:58:00+01:00  146.488998  146.542007  146.464996  146.503998
# 2024-08-02 21:59:00+01:00  146.511993  146.539993  146.477997  146.518997
#
#                            Volume  Dividends  Stock Splits
# Datetime
# 2024-08-01 23:55:00+01:00       0        0.0           0.0
# 2024-08-01 23:56:00+01:00       0        0.0           0.0
# 2024-08-01 23:57:00+01:00       0        0.0           0.0
# 2024-08-01 23:58:00+01:00       0        0.0           0.0
# 2024-08-02 00:00:00+01:00       0        0.0           0.0
# ...                           ...        ...           ...
# 2024-08-02 21:55:00+01:00       0        0.0           0.0
# 2024-08-02 21:56:00+01:00       0        0.0           0.0
# 2024-08-02 21:57:00+01:00       0        0.0           0.0
# 2024-08-02 21:58:00+01:00       0        0.0           0.0
# 2024-08-02 21:59:00+01:00       0        0.0           0.0
#
# [1322 rows x 7 columns]

# %%
mpf.plot(df, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4))
# Out:
# /home/bitwalk/MyProjects/PySide6_sample/venv/lib/python3.12/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
#mpf.plot(df, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4),
#         savefig=dict(fname='yfinance_test_001_1.jpeg', dpi=100))

# %%
df.index = df.index.tz_convert('Asia/Tokyo')
df
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-08-02 07:55:00+09:00  149.319000  149.320999  149.257004  149.281998
# 2024-08-02 07:56:00+09:00  149.285004  149.319000  149.279999  149.315994
# 2024-08-02 07:57:00+09:00  149.309006  149.341003  149.309006  149.330994
# 2024-08-02 07:58:00+09:00  149.334000  149.343994  149.317001  149.317001
# 2024-08-02 08:00:00+09:00  149.304001  149.311005  149.246994  149.272995
# ...                               ...         ...         ...         ...
# 2024-08-03 05:55:00+09:00  146.567993  146.574997  146.507004  146.528000
# 2024-08-03 05:56:00+09:00  146.526993  146.539993  146.475006  146.535004
# 2024-08-03 05:57:00+09:00  146.542999  146.550003  146.468002  146.481995
# 2024-08-03 05:58:00+09:00  146.488998  146.542007  146.464996  146.503998
# 2024-08-03 05:59:00+09:00  146.511993  146.539993  146.477997  146.518997
#
#                            Volume  Dividends  Stock Splits
# Datetime
# 2024-08-02 07:55:00+09:00       0        0.0           0.0
# 2024-08-02 07:56:00+09:00       0        0.0           0.0
# 2024-08-02 07:57:00+09:00       0        0.0           0.0
# 2024-08-02 07:58:00+09:00       0        0.0           0.0
# 2024-08-02 08:00:00+09:00       0        0.0           0.0
# ...                           ...        ...           ...
# 2024-08-03 05:55:00+09:00       0        0.0           0.0
# 2024-08-03 05:56:00+09:00       0        0.0           0.0
# 2024-08-03 05:57:00+09:00       0        0.0           0.0
# 2024-08-03 05:58:00+09:00       0        0.0           0.0
# 2024-08-03 05:59:00+09:00       0        0.0           0.0
#
# [1322 rows x 7 columns]

# %%
mpf.plot(df, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4))
# Out:
# /home/bitwalk/MyProjects/PySide6_sample/venv/lib/python3.12/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
#mpf.plot(df, type='candle', style='binance', ylabel='USD - JPY', figratio=(12, 4),
#         savefig=dict(fname='yfinance_test_001_2.jpeg', dpi=100))
